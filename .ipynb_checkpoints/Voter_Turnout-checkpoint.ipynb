# %%
import pandas as pd
import geoplot as gplt
import geopandas as gpd
import seaborn as sns
import geoplot.crs as gcrs

# %%
cont_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa')).set_index('state')
cont_usa.head()
# Out:
#              adm1_code  population  \
# state
# Minnesota     USA-3514     5303925
# Montana       USA-3515      989415
# North Dakota  USA-3516      672591
# Idaho         USA-3518     1567582
# Washington    USA-3519     6724540
#
#                                                        geometry
# state
# Minnesota     POLYGON ((-89.59941 48.01027, -89.48888 48.013...
# Montana       POLYGON ((-111.19419 44.56116, -111.29155 44.7...
# North Dakota  POLYGON ((-96.60136 46.35136, -96.53891 46.199...
# Idaho         POLYGON ((-111.04973 44.48816, -111.05025 42.0...
# Washington    POLYGON ((-116.99807 46.33017, -116.90653 46.1...

# %%
obama_general_election = pd.read_csv('2008_November_General_Election.csv').set_index('state')
obama_general_election.head()
# Out:
#            VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# state
# Alabama                        61.0%              60.8%              58.4%
# Alaska                         68.3%              68.0%              64.3%
# Arizona                        57.4%              56.7%              49.1%
# Arkansas                       52.9%              52.5%              50.0%
# California                     61.7%              60.9%              49.5%
#
#            Total Ballots Counted Highest Office         VEP         VAP  \
# state
# Alabama                2,105,622      2,099,819   3,454,510   3,595,708
# Alaska                   327,341        326,197     479,429     507,645
# Arizona                2,320,851      2,293,475   4,046,075   4,673,718
# Arkansas               1,095,958      1,086,617   2,071,563   2,174,846
# California            13,743,177     13,561,900  22,261,504  27,411,094
#
#            Non-citizen   Prison Probation   Parole Total Ineligible Felon  \
# state
# Alabama           2.2%   30,508    53,252    8,042                 61,155
# Alaska            3.7%    5,014     6,708    1,732                  9,234
# Arizona          11.6%   39,589    82,232    7,534                 84,472
# Arkansas          2.9%   14,716    31,169   19,908                 40,255
# California       17.9%  173,670         0  120,753                234,047
#
#            Overseas Eligible
# state
# Alabama               74,079
# Alaska                60,686
# Arizona               90,036
# Arkansas              43,963
# California           486,207

# %%
obama_general_election = cont_usa.join(obama_general_election)

# %%
obama_general_election.head()
# Out:
#              adm1_code  population  \
# state
# Minnesota     USA-3514     5303925
# Montana       USA-3515      989415
# North Dakota  USA-3516      672591
# Idaho         USA-3518     1567582
# Washington    USA-3519     6724540
#
#                                                        geometry  \
# state
# Minnesota     POLYGON ((-89.59941 48.01027, -89.48888 48.013...
# Montana       POLYGON ((-111.19419 44.56116, -111.29155 44.7...
# North Dakota  POLYGON ((-96.60136 46.35136, -96.53891 46.199...
# Idaho         POLYGON ((-111.04973 44.48816, -111.05025 42.0...
# Washington    POLYGON ((-116.99807 46.33017, -116.90653 46.1...
#
#              VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# state
# Minnesota                        78.1%              77.8%              73.2%
# Montana                          67.1%              66.3%              65.1%
# North Dakota                     63.6%              62.7%              61.7%
# Idaho                            64.8%              63.6%              58.6%
# Washington                       67.3%              66.6%              60.3%
#
#              Total Ballots Counted Highest Office        VEP        VAP  \
# state
# Minnesota                2,921,147      2,910,369  3,740,142  3,975,974
# Montana                    497,599        491,960    741,853    755,384
# North Dakota               321,133        316,621    504,762    512,768
# Idaho                      667,506        655,032  1,029,416  1,117,842
# Washington               3,071,587      3,036,878  4,561,163  5,032,960
#
#              Non-citizen  Prison Probation  Parole Total Ineligible Felon  \
# state
# Minnesota           4.0%   9,910   127,627   5,081                 76,264
# Montana             1.3%   3,545         0       0                  3,545
# North Dakota        1.3%   1,452         0       0                  1,452
# Idaho               4.9%   7,290    49,513   3,361                 33,727
# Washington          7.8%  17,926   113,134  11,768                 80,377
#
#              Overseas Eligible
# state
# Minnesota               70,063
# Montana                 22,898
# North Dakota            11,179
# Idaho                   26,779
# Washington             138,296

# %%
gplt.choropleth(obama_general_election, projection=gcrs.AlbersEqualArea(), hue='VEP')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b0bcc572e0bc> in <module>
# ----> 1 gplt.choropleth(obama_general_election, projection=gcrs.AlbersEqualArea(), hue='VEP')
#
# NameError: name 'gcrs' is not defined
